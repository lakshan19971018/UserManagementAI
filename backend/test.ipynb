# %%
import os 
from dotenv import load_dotenv
from groq import Groq
from backend.app.core.config import GORQ_API 



client = Groq(
    api_key="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"  ,
)
chat_completion = client.chat.completions.create(

        messages=[
        # Set an optional system message. This sets the behavior of the
        # assistant and can be used to provide specific instructions for
        # how it should behave throughout the conversation.
        {
            "role": "system",
            "content": "you are a helpful assistant."
        },

         {
            "role": "user",
            "content": "What is the capital of France?"
        },
    ],

    model="llama-3.3-70b-versatile",
    temperature=0.3,
    top_p= 0.8,
    
)

print(chat_completion.choices[0].message.content)
# Out:
# The capital of France is Paris.

# %%
import os
from dotenv import load_dotenv
from groq import Groq

# Load API key from environment variables or config
load_dotenv()
api_key="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"  ,

# Initialize Groq client
client = Groq(api_key="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"  )

def query_groq(question: str) -> str:
    """
    Query the Groq API with a user question.
    
    Args:
        question (str): The question to ask the assistant.
        
    Returns:
        str: The assistant's response.
    """
    try:
        # Send request to the Groq API
        chat_completion = client.chat.completions.create(
            messages=[
                # Define the assistant's behavior
                {
                    "role": "system",
                    "content": "You are a helpful assistant."
                },
                # Add the user's question
                {
                    "role": "user",
                    "content": question
                },
            ],
            model="llama-3.3-70b-versatile",  # Specify the model
            temperature=0.3,  # Control response creativity
            top_p=0.8,        # Control response diversity
        )
        
        # Extract the assistant's response
        return chat_completion.choices[0].message.content
    except Exception as e:
        return f"Error: {str(e)}"

# Example usage of the query method
if __name__ == "__main__":
    question = "What is the capital of France?"
    response = query_groq(question)
    print("Assistant's Response:", response)
# Out:
# Assistant's Response: The capital of France is Paris.

# %%
from groq import Groq
from sqlalchemy import create_engine, text
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()
GORQ_API = os.getenv("GORQ_API", "your_api_key_here")
DATABASE_URL = os.getenv("DATABASE_URL", "mysql+pymysql://user:password@localhost/dbname")

# Initialize Groq client
client = Groq(api_key="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")

# Initialize SQLAlchemy database connection
engine = create_engine("mysql://root:root@localhost/users")

def get_database_schema() -> str:
    """
    Extract and return the database schema as a string for the language model to understand.
    """
    schema_description = """
    The database contains the following tables:
        __tablename__ = 'users'

    id = Column(Integer, primary_key=True, index=True)
    name = Column(String(255), index=True)
    email = Column(String(255), unique=True, index=True)
    nation_id = Column(String(255), unique=True, index=True)
    file_code = Column(String(255), unique=True, index=True)
    register_date = Column(Date)
    promotion_date = Column(Date)
    gender = Column(String(10),nullable=True)
    salary = Column(Integer)
    level = Column(String(10),nullable=True)
    address = Column(String(255), nullable=True)
    category_id = Column(Integer, ForeignKey("categories.id"))
    category = relationship("Category", back_populates="users", lazy="joined")`

        __tablename__ = "admins"

    id = Column(Integer,primary_key=True,index=True)
    email  = Column(String(255), unique=True, index=True, nullable=False)
    hashed_password = Column(String(255), nullable=False)
    created_at = Column(DateTime, nullable=False,server_default=func.now())

        __tablename__ = 'categories'

    id = Column(Integer, primary_key=True, index=True)
    name = Column(String(255), unique=True, index=True)
    users = relationship("User", back_populates="category", lazy="select")

    """
    return schema_description

def ask_question(question: str) -> str:
    """
    Ask a question about the database and retrieve the answer using the Groq client.
    """
    schema = get_database_schema()
    print(schema)
    try:
        # Send the schema and user question to the model
        chat_completion = client.chat.completions.create(
            messages=[
                {
                    "role": "system",
                    "content": (
                        "You are a helpful assistant with access to the following database schema. give answers not sql query "
                        "Answer the user's question based on this schema:\n" + schema
                    ),
                },
                {
                    "role": "user",
                    "content": question,
                },
            ],
            model="llama-3.3-70b-versatile",
            temperature=0.3,
            top_p=0.8,
        )
        return chat_completion.choices[0].message.content
    except Exception as e:
        return f"Error: {str(e)}"

def main():
    user_question = "what is the name details of user who hase id is 2 "
    answer = ask_question(user_question)
    print("Answer:", answer)

if __name__ == "__main__":
    main()
# Out:
#     The database contains the following tables:
#         __tablename__ = 'users'
#
#     id = Column(Integer, primary_key=True, index=True)
#     name = Column(String(255), index=True)
#     email = Column(String(255), unique=True, index=True)
#     nation_id = Column(String(255), unique=True, index=True)
#     file_code = Column(String(255), unique=True, index=True)
#     register_date = Column(Date)
#     promotion_date = Column(Date)
#     gender = Column(String(10),nullable=True)
#     salary = Column(Integer)
#     level = Column(String(10),nullable=True)
#     address = Column(String(255), nullable=True)
#     category_id = Column(Integer, ForeignKey("categories.id"))
#     category = relationship("Category", back_populates="users", lazy="joined")`
#
#         __tablename__ = "admins"
#
#     id = Column(Integer,primary_key=True,index=True)
#     email  = Column(String(255), unique=True, index=True, nullable=False)
#     hashed_password = Column(String(255), nullable=False)
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection details
DATABASE_TYPE = "mysql"  # Use appropriate database type
USER = "your_username"
PASSWORD = "your_password"
HOST = "localhost"  # Replace with your database host
PORT = "3306"  # Default MySQL port
DATABASE = "your_database_name"

# Create the database connection
engine = create_engine("mysql://root:root@localhost/users")

# Query the database and load data into a DataFrame
query = "SELECT * FROM users"
df = pd.read_sql(query, engine)

# Display the DataFrame
print(df)
# Out:
#    id           name                     email nation_id file_code  \
# 0   3   Samuel Green   samuelgreen@example.com  US458732    GRN876
# 1   4  Sophia Turner  sophiaturner@example.com  UK567891    TRN123
# 2   6   Liam Johnson   liamjohnson@example.com  CA123456    JOH987
# 3   7   Ava Mitchell   avamitchell@example.com  AU999321    MIT556
# 4   8  Oliver Harris  oliverharris@example.com  IN456789    HAR123
#
#   register_date promotion_date  gender  salary      level  \
# 0    2025-01-08     2025-01-08    Male   52000     Senior
# 1    2025-01-08     2025-01-08  Female   48000     Junior
# 2    2025-01-08     2025-01-08    Male   60000       Lead
# 3    2025-01-08     2025-01-08  Female   52000  Associate
# 4    2025-01-08     2025-01-08    Male   43000     Intern
#
#                                    address  category_id
# 0              1123 Oakwood Rd, Dallas, TX            1
# 1                 456 Maple St, London, UK            2
# ...

# %%
data_json = df.to_json(orient='records')
data_json
# Out:
# '[{"id":3,"name":"Samuel Green","email":"samuelgreen@example.com","nation_id":"US458732","file_code":"GRN876","register_date":1736294400000,"promotion_date":1736294400000,"gender":"Male","salary":52000,"level":"Senior","address":"1123 Oakwood Rd, Dallas, TX","category_id":1},{"id":4,"name":"Sophia Turner","email":"sophiaturner@example.com","nation_id":"UK567891","file_code":"TRN123","register_date":1736294400000,"promotion_date":1736294400000,"gender":"Female","salary":48000,"level":"Junior","address":"456 Maple St, London, UK","category_id":2},{"id":6,"name":"Liam Johnson","email":"liamjohnson@example.com","nation_id":"CA123456","file_code":"JOH987","register_date":1736294400000,"promotion_date":1736294400000,"gender":"Male","salary":60000,"level":"Lead","address":"789 Birch Ave, Toronto, Canada","category_id":3},{"id":7,"name":"Ava Mitchell","email":"avamitchell@example.com","nation_id":"AU999321","file_code":"MIT556","register_date":1736294400000,"promotion_date":1736294400000,"ge
# ...

# %%
from groq import Groq
from sqlalchemy import create_engine, text
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()
GORQ_API = os.getenv("GORQ_API", "your_api_key_here")
DATABASE_URL = os.getenv("DATABASE_URL", "mysql+pymysql://user:password@localhost/dbname")

# Initialize Groq client
client = Groq(api_key="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")

# Initialize SQLAlchemy database connection
engine = create_engine("mysql://root:root@localhost/users")



def ask_question(question: str) -> str:
    """
    Ask a question about the database and retrieve the answer using the Groq client.
    """

    try:
        # Send the schema and user question to the model
        chat_completion = client.chat.completions.create(
            messages=[
                {
                    "role": "system",
                    "content": (
                        "You are a helpful assistant with access to the following database schema. give answers not sql query "
                        "Answer the user's question based on the database :\n" 
                    ),
                },
                {
                    "role": "user",
                    "content": question,
                },
            ],
            model="llama-3.3-70b-versatile",
            temperature=0.3,
            top_p=0.8,
        )
        return chat_completion.choices[0].message.content
    except Exception as e:
        return f"Error: {str(e)}"

def main():
    user_question = f"What is the total salary of all users?\n{data_json }"
    answer = ask_question(user_question)
    print("Answer:", answer)

if __name__ == "__main__":
    main()
# Out:
# Answer: The total salary of all users is $215000.
#
# Here's the calculation:
# 52000 + 48000 + 60000 + 52000 + 43000 = 215000.
